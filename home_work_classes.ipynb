# %% [markdown]
# ## Задание № 1. Наследование
#
# ### Исходя из квиза к предыдущему занятию, у нас уже есть класс преподавателей и класс студентов (вы можете взять этот код за основу или написать свой). Студентов пока оставим без изменения, а вот преподаватели бывают разные, поэтому теперь класс Mentor должен стать родительским классом, а от него нужно реализовать наследование классов Lecturer (лекторы) и Reviewer (эксперты, проверяющие домашние задания).Очевидно, имя, фамилия и список закрепленных курсов логично реализовать на уровне родительского класса. А чем же будут специфичны дочерние классы? Об этом в следующих заданиях.

# %% [markdown]
# ## VЗадание № 2. Атрибуты и взаимодействие классов.
# ### В квизе к предыдущей лекции мы реализовали возможность выставлять студентам оценки за домашние задания. Теперь это могут делать только Reviewer (реализуйте такой метод)! А что могут делать лекторы? Получать оценки за лекции от студентов :) Реализуйте метод выставления оценок лекторам у класса Student (оценки по 10-балльной шкале, хранятся в атрибуте-словаре у Lecturer, в котором ключи – названия курсов, а значения – списки оценок). Лектор при этом должен быть закреплен за тем курсом, на который записан студент.

# %% [markdown]
# ## Задание № 3. Полиморфизм и магические методы
# ### Перегрузите магический метод __str__ у всех классов.
# У проверяющих он должен выводить информацию в следующем виде:
#
# print(some_reviewer)
# Имя: Some
# Фамилия: Buddy
# У лекторов:
#
# print(some_lecturer)
# Имя: Some
# Фамилия: Buddy
# Средняя оценка за лекции: 9.9
# А у студентов так:
#
# print(some_student)
# Имя: Ruoy
# Фамилия: Eman
# Средняя оценка за домашние задания: 9.9
# Курсы в процессе изучения: Python, Git
# Завершенные курсы: Введение в программирование
# ### Реализуйте возможность сравнивать (через операторы сравнения) между собой лекторов по средней оценке за лекции и студентов по средней оценке за домашние задания.

# %% [markdown]
# ## Задание № 4. Полевые испытания
# ### Создайте по 2 экземпляра каждого класса, вызовите все созданные методы, а также реализуйте две функции:
#
# для подсчета средней оценки за домашние задания по всем студентам в рамках конкретного курса (в качестве аргументов принимаем список студентов и название курса);
# для подсчета средней оценки за лекции всех лекторов в рамках курса (в качестве аргумента принимаем список лекторов и название курса).

# %%
class Student:
    def __init__(self, name, surname, gender):
        self.name = name
        self.surname = surname
        self.gender = gender
        self.finished_courses = []
        self.courses_in_progress = []
        self.grades = {}
        
    
    def end_courses(self, course_end):    
        self.finished_courses.append(course_end)
    
    def add_courses(self, course_name):
        self.courses_in_progress.append(course_name)   
    
    def average_grades(self):
        sum_grad = 0
        student_average =[]
        for x in self.grades.values():
            sum_grad += sum(x) / len(x)
            student_average.append(x)
            result = round(sum_grad / len(student_average), 1)
        return result


    def rate_lec(self, lecturer, course, grade):
        if isinstance(lecturer, Lecturer) and course in lecturer.courses_att and course in self.courses_in_progress:
            if course in lecturer.grades_lecturers:
                    lecturer.grades_lecturers[course] += [grade]
            else:
                    lecturer.grades_lecturers[course] = [grade]
        else:
            return 'Ошибка'             
    
    def __str__(self):
        result_student = f'Имя:\n{self.name} \nФамилия:\n{self.surname} \nСредняя оценка за домашние задания:\n{self.average_grades()}\nКурсы в процессе изучения:\n{", " .join(self.courses_in_progress)}\nЗавершенные курсы:\n{", " .join(self.finished_courses)}'
        return result_student

    def __lt__(self, other):
        if not isinstance(other, Student):
            print('Такого студента нет.')
            return 
        return self.average_grades() < other.average_grades()  


class Mentor:
    def __init__(self, name, surname):
        self.name = name
        self.surname = surname
        self.courses_attached = []    

class Rewiever(Mentor):
    def __init__(self, name, surname):
        super().__init__(name, surname)
    
    def rate_hw(self, student, course, grade):
        if isinstance(student, Student) and course in self.courses_attached and course in student.courses_in_progress:
            if course in student.grades:
                student.grades[course] += [grade]
            else:
                student.grades[course] = [grade]
        else:
            return 'Ошибка'       

    def __str__(self):
        result_rewiever = f'Имя:\n{self.name} \nФамилия:\n{self.surname}'
        return result_rewiever    


class Lecturer(Mentor):
    
    def __init__(self, name, surname):
        super().__init__(name, surname) 
        
        self.grades_lecturers = {}
        self.courses_att =[]               
    
    def average_grades_lecturer(self):
        sum_grad_lec = 0
        lecturer_average =[]
        for y in self.grades_lecturers.values():
            sum_grad_lec += sum(y) / len(y)
            lecturer_average.append(y)
            result = round(sum_grad_lec / len(lecturer_average), 1)
        return result
    
    def __str__(self):
        result_lecturer = f'Имя:\n{self.name} \nФамилия:\n{self.surname} \nСредняя оценка за лекции:\n{self.average_grades_lecturer()}'
        return result_lecturer

    def __lt__(self, other):
        if not isinstance(other, Lecturer):
            print('Такого преподавателя нет.')
            return 
        return self.average_grades_lecturer() < other.average_grades_lecturer()      

lecturer_1 = Lecturer("Ivan", "Ivanov")
lecturer_1.courses_att += ['Python']
lecturer_1.courses_att += ['GIT']

lecturer_2 = Lecturer("Oleg", "Olegov")
lecturer_2.courses_att += ['GIT']
lecturer_2.courses_att += ['Python']


rewiever_1 = Rewiever("Petr", "Petrov")
rewiever_1.courses_attached += ['Python']

rewiever_2 = Rewiever("Renat", "Renatov")
rewiever_2.courses_attached += ['GIT']

student_1 = Student('Sidor', 'Sidorov', 'men')
student_1.courses_in_progress += ['Python']
student_1.courses_in_progress += ['GIT']
student_1.finished_courses += ['Введение в программирование'] 
student_2 = Student('Marina', 'Marinina', 'woman')
student_2.courses_in_progress += ['Python']
student_2.courses_in_progress += ['GIT']
student_2.finished_courses += ['Введение в программирование']


rewiever_1.rate_hw(student_1, 'Python', 9)
rewiever_1.rate_hw(student_1, 'Python', 10)
rewiever_1.rate_hw(student_1, 'Python', 8) 
rewiever_1.rate_hw(student_1, 'Python', 8)
rewiever_2.rate_hw(student_1, 'GIT', 9)
rewiever_2.rate_hw(student_1, 'GIT', 9)
rewiever_2.rate_hw(student_1, 'GIT', 10)
rewiever_2.rate_hw(student_1, 'GIT', 9)

student_1.rate_lec(lecturer_1, 'Python', 10)
student_1.rate_lec(lecturer_1, 'Python', 9)
student_1.rate_lec(lecturer_1, 'Python', 8)
student_1.rate_lec(lecturer_1, 'GIT', 9)
student_1.rate_lec(lecturer_2, 'GIT', 10)
student_1.rate_lec(lecturer_2, 'GIT', 9)
student_1.rate_lec(lecturer_2, 'GIT', 10)
student_1.rate_lec(lecturer_2, 'Python', 8)


rewiever_1.rate_hw(student_2, 'Python', 7)
rewiever_1.rate_hw(student_2, 'Python', 9)
rewiever_1.rate_hw(student_2, 'Python', 8) 
rewiever_1.rate_hw(student_2, 'Python', 10)
rewiever_2.rate_hw(student_2, 'GIT', 10)
rewiever_2.rate_hw(student_2, 'GIT', 9)
rewiever_2.rate_hw(student_2, 'GIT', 8)
rewiever_2.rate_hw(student_2, 'GIT', 9)

student_2.rate_lec(lecturer_1, 'Python', 8)
student_2.rate_lec(lecturer_1, 'Python', 9)
student_2.rate_lec(lecturer_1, 'Python', 7)
student_2.rate_lec(lecturer_1, 'GIT', 7)
student_2.rate_lec(lecturer_2, 'GIT', 8)
student_2.rate_lec(lecturer_2, 'GIT', 9)
student_2.rate_lec(lecturer_2, 'GIT', 10)
student_2.rate_lec(lecturer_2, 'Python', 7)



print(rewiever_1) 
print(rewiever_2)
print(lecturer_1)
print(lecturer_1.grades_lecturers)
print(lecturer_2)
print(lecturer_2.grades_lecturers)
print(student_1) 
print(student_1.grades)
print(student_2) 
print(student_2.grades)
print(student_1 < student_2)
print(lecturer_1 < lecturer_2)


list_stud = [student_1, student_2]
def av_stud(list_stud, course):
    sum_grad_st = 0
    quantity = 0
    for a in list_stud:
        for z in a.grades[course]:
            sum_grad_st += z
            quantity += 1
            
            result = round(sum_grad_st/quantity, 1)
    return result

list_lec = [lecturer_1, lecturer_2]
def av_lec(list_lec, course):
    sum_grade_lec = 0
    quantity = 0
    for a in list_lec:
        for z in a.grades_lecturers[course]:
            sum_grade_lec += z
            quantity += 1
            
            result = round(sum_grade_lec/quantity, 1)
    return result    


print(f'Средняя оценка студентов на курсе Python: {av_stud(list_stud, "Python")}')
print(f'Средняя оценка студентов на курсе GIT: {av_stud(list_stud, "GIT")}')
print(f'Средняя оценка преподавателей на курсе Python: {av_lec(list_lec, "Python")}')
print(f'Средняя оценка преподавателей на курсе GIT: {av_lec(list_lec, "GIT")}')
# Out:
# Имя:
# Petr
# Фамилия:
# Petrov
# Имя:
# Renat
# Фамилия:
# Renatov
# Имя:
# Ivan
# Фамилия:
# Ivanov
# Средняя оценка за лекции:
# 8.2
# {'Python': [10, 9, 8, 8, 9, 7], 'GIT': [9, 7]}
# Имя:
# Oleg
# Фамилия:
# Olegov
# Средняя оценка за лекции:
# 8.4
# {'GIT': [10, 9, 10, 8, 9, 10], 'Python': [8, 7]}
# Имя:
# Sidor
# Фамилия:
# Sidorov
# Средняя оценка за домашние задания:
# 9.0
# Курсы в процессе изучения:
# Python, GIT
# Завершенные курсы:
# Введение в программирование
# {'Python': [9, 10, 8, 8], 'GIT': [9, 9, 10, 9]}
# Имя:
# Marina
# Фамилия:
# Marinina
# Средняя оценка за домашние задания:
# 8.8
# Курсы в процессе изучения:
# Python, GIT
# Завершенные курсы:
# Введение в программирование
# {'Python': [7, 9, 8, 10], 'GIT': [10, 9, 8, 9]}
# False
# True
# Средняя оценка студентов на курсе Python: 8.6
# Средняя оценка студентов на курсе GIT: 9.1
# Средняя оценка преподавателей на курсе Python: 8.2
# Средняя оценка преподавателей на курсе GIT: 9.0
